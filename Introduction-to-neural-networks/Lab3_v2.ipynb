# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense

# %%
ds = pd.read_csv('spotify-2023.csv', encoding='latin-1')
ds.keys()
# Out:
# Index(['track_name', 'artist(s)_name', 'artist_count', 'released_year',
#        'released_month', 'released_day', 'in_spotify_playlists',
#        'in_spotify_charts', 'streams', 'in_apple_playlists', 'in_apple_charts',
#        'in_deezer_playlists', 'in_deezer_charts', 'in_shazam_charts', 'bpm',
#        'key', 'mode', 'danceability_%', 'valence_%', 'energy_%',
#        'acousticness_%', 'instrumentalness_%', 'liveness_%', 'speechiness_%'],
#       dtype='object')

# %%
ds.drop('track_name', inplace = True, axis = 1)
ds.drop('artist(s)_name', inplace = True, axis = 1)
LE = LabelEncoder()
ds['key'] = LE.fit_transform(ds['key'])
ds['mode'] = LE.fit_transform(ds['mode'])
ds['streams'] = LE.fit_transform(ds['streams'])
ds['in_deezer_playlists'] = LE.fit_transform(ds['in_deezer_playlists'])
ds['in_shazam_charts'] = LE.fit_transform(ds['in_shazam_charts'])
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 953 entries, 0 to 952
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   artist_count          953 non-null    int64
#  1   released_year         953 non-null    int64
#  2   released_month        953 non-null    int64
#  3   released_day          953 non-null    int64
#  4   in_spotify_playlists  953 non-null    int64
#  5   in_spotify_charts     953 non-null    int64
#  6   streams               953 non-null    int32
#  7   in_apple_playlists    953 non-null    int64
#  8   in_apple_charts       953 non-null    int64
#  9   in_deezer_playlists   953 non-null    int32
#  10  in_deezer_charts      953 non-null    int64
#  11  in_shazam_charts      953 non-null    int32
#  12  bpm                   953 non-null    int64
#  13  key                   953 non-null    int32
#  14  mode                  953 non-null    int32
#  15  danceability_%        953 non-null    int64
#  16  valence_%             953 non-null    int64
#  17  energy_%              953 non-null    int64
#  18  acousticness_%        953 non-null    int64
#  19  instrumentalness_%    953 non-null    int64
#  20  liveness_%            953 non-null    int64
#  21  speechiness_%         953 non-null    int64
# dtypes: int32(5), int64(17)
# memory usage: 145.3 KB

# %%
scaler = MinMaxScaler()
names = ds.columns
ds_scaler = scaler.fit_transform(ds)
ds = pd.DataFrame(ds_scaler, columns=names)

ds.loc[ds["in_spotify_charts"] < 0.1, "in_spotify_charts"] = 1 #very popular 1st class
ds.loc[ds["in_spotify_charts"] >= 0.1, "in_spotify_charts"] = 0 #not that popular 2nd class
ds.head()
# Out:
#    artist_count  released_year  released_month  released_day  \
# 0      0.142857       1.000000        0.545455      0.433333
# 1      0.000000       1.000000        0.181818      0.733333
# 2      0.000000       1.000000        0.454545      0.966667
# 3      0.000000       0.956989        0.636364      0.733333
# 4      0.000000       1.000000        0.363636      0.566667
#
#    in_spotify_playlists  in_spotify_charts   streams  in_apple_playlists  \
# 0              0.009874                0.0  0.164557            0.063988
# 1              0.027295                0.0  0.131857            0.071429
# 2              0.025838                0.0  0.159283            0.139881
# 3              0.148051                0.0  0.911392            0.172619
# 4              0.058676                0.0  0.526371            0.125000
#
#    in_apple_charts  in_deezer_playlists  ...       bpm       key  mode  \
# 0         0.956364             0.625360  ...  0.425532  0.181818   0.0
# 1         0.458182             0.755043  ...  0.191489  0.272727   0.0
# 2         0.752727             0.971182  ...  0.517730  0.636364   0.0
# 3         0.752727             0.144092  ...  0.744681  0.000000   0.0
# 4         0.483636             0.951009  ...  0.560284  0.000000   1.0
#
#    danceability_%  valence_%  energy_%  acousticness_%  instrumentalness_%  \
# 0        0.780822   0.913978  0.840909        0.319588            0.000000
# 1        0.657534   0.612903  0.738636        0.072165            0.000000
# 2        0.383562   0.301075  0.500000        0.175258            0.000000
# 3        0.438356   0.580645  0.715909        0.113402            0.000000
# 4        0.575342   0.204301  0.806818        0.144330            0.692308
#
#    liveness_%  speechiness_%
# 0    0.053191       0.032258
# 1    0.074468       0.032258
# 2    0.297872       0.064516
# 3    0.085106       0.209677
# 4    0.085106       0.064516
#
# [5 rows x 22 columns]

# %%
X = ds.drop('in_spotify_charts', axis=1);
y = ds['in_spotify_charts'];

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 123)

y_train = to_categorical(y_train, 2)
y_test = to_categorical(y_test, 2)

# %%
fully_con_feed_forward_net = Sequential(name = "FFNN")

fully_con_feed_forward_net.add(Dense(20, input_shape=(21,), activation = 'relu'))
fully_con_feed_forward_net.add(Dense(50, activation = 'relu'))
fully_con_feed_forward_net.add(Dense(2, activation = 'sigmoid')) #changed activation from "relu" to "sigmoid"

fully_con_feed_forward_net.compile(loss="binary_crossentropy", metrics = ['accuracy'], optimizer = 'adam')
res = fully_con_feed_forward_net.fit(X_train, y_train, epochs = 100)
# Out:
# WARNING:tensorflow:From C:\Users\Andrii\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\Andrii\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/100
# WARNING:tensorflow:From C:\Users\Andrii\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\Andrii\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 24/24 [==============================] - 1s 1ms/step - loss: 0.4462 - accuracy: 1.0000
# Epoch 2/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1869 - accuracy: 1.0000
# Epoch 3/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0408 - accuracy: 1.0000
# Epoch 4/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0090 - accuracy: 1.0000
# Epoch 5/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 6/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 7/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 8/100
# 24/24 [==============================] - 0s 1ms/step - loss: 8.6500e-04 - accuracy: 1.0000
# Epoch 9/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2615e-04 - accuracy: 1.0000
# Epoch 10/100
# 24/24 [==============================] - 0s 1ms/step - loss: 4.6274e-04 - accuracy: 1.0000
# Epoch 11/100
# 24/24 [==============================] - 0s 1ms/step - loss: 3.4483e-04 - accuracy: 1.0000
# Epoch 12/100
# 24/24 [==============================] - 0s 1ms/step - loss: 2.5870e-04 - accuracy: 1.0000
# Epoch 13/100
# 24/24 [==============================] - 0s 1ms/step - loss: 1.9618e-04 - accuracy: 1.0000
# Epoch 14/100
# 24/24 [==============================] - 0s 1ms/step - loss: 1.5118e-04 - accuracy: 1.0000
# Epoch 15/100
# 24/24 [==============================] - 0s 1ms/step - loss: 1.1930e-04 - accuracy: 1.0000
# Epoch 16/100
# 24/24 [==============================] - 0s 1ms/step - loss: 9.6143e-05 - accuracy: 1.0000
# Epoch 17/100
# 24/24 [==============================] - 0s 1ms/step - loss: 7.8516e-05 - accuracy: 1.0000
# Epoch 18/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.5465e-05 - accuracy: 1.0000
# Epoch 19/100
# 24/24 [==============================] - 0s 1ms/step - loss: 5.5097e-05 - accuracy: 1.0000
# Epoch 20/100
# 24/24 [==============================] - 0s 1ms/step - loss: 4.7018e-05 - accuracy: 1.0000
# Epoch 21/100
# 24/24 [==============================] - 0s 1ms/step - loss: 4.0612e-05 - accuracy: 1.0000
# Epoch 22/100
# 24/24 [==============================] - 0s 1ms/step - loss: 3.5276e-05 - accuracy: 1.0000
# Epoch 23/100
# 24/24 [==============================] - 0s 1ms/step - loss: 3.1052e-05 - accuracy: 1.0000
# Epoch 24/100
# 24/24 [==============================] - 0s 1ms/step - loss: 2.7484e-05 - accuracy: 1.0000
# Epoch 25/100
# 24/24 [==============================] - 0s 1ms/step - loss: 2.4501e-05 - accuracy: 1.0000
# Epoch 26/100
# 24/24 [==============================] - 0s 1ms/step - loss: 2.1927e-05 - accuracy: 1.0000
# Epoch 27/100
# 24/24 [==============================] - 0s 1ms/step - loss: 1.9775e-05 - accuracy: 1.0000
# Epoch 28/100
# 24/24 [==============================] - 0s 1ms/step - loss: 1.7923e-05 - accuracy: 1.0000
# Epoch 29/100
# 24/24 [==============================] - 0s 1ms/step - loss: 1.6313e-05 - accuracy: 1.0000
# Epoch 30/100
# 24/24 [==============================] - 0s 1ms/step - loss: 1.4908e-05 - accuracy: 1.0000
# Epoch 31/100
# 24/24 [==============================] - 0s 1ms/step - loss: 1.3661e-05 - accuracy: 1.0000
# Epoch 32/100
# 24/24 [==============================] - 0s 1ms/step - loss: 1.2570e-05 - accuracy: 1.0000
# Epoch 33/100
# 24/24 [==============================] - 0s 1ms/step - loss: 1.1621e-05 - accuracy: 1.0000
# Epoch 34/100
# 24/24 [==============================] - 0s 1ms/step - loss: 1.0774e-05 - accuracy: 1.0000
# Epoch 35/100
# 24/24 [==============================] - 0s 1ms/step - loss: 9.9950e-06 - accuracy: 1.0000
# Epoch 36/100
# 24/24 [==============================] - 0s 1ms/step - loss: 9.3031e-06 - accuracy: 1.0000
# Epoch 37/100
# 24/24 [==============================] - 0s 1ms/step - loss: 8.6826e-06 - accuracy: 1.0000
# Epoch 38/100
# 24/24 [==============================] - 0s 1ms/step - loss: 8.1234e-06 - accuracy: 1.0000
# Epoch 39/100
# 24/24 [==============================] - 0s 1ms/step - loss: 7.6194e-06 - accuracy: 1.0000
# Epoch 40/100
# 24/24 [==============================] - 0s 2ms/step - loss: 7.1434e-06 - accuracy: 1.0000
# Epoch 41/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.7294e-06 - accuracy: 1.0000
# Epoch 42/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.3407e-06 - accuracy: 1.0000
# Epoch 43/100
# 24/24 [==============================] - 0s 1ms/step - loss: 5.9863e-06 - accuracy: 1.0000
# Epoch 44/100
# 24/24 [==============================] - 0s 1ms/step - loss: 5.6563e-06 - accuracy: 1.0000
# Epoch 45/100
# 24/24 [==============================] - 0s 1ms/step - loss: 5.3582e-06 - accuracy: 1.0000
# Epoch 46/100
# 24/24 [==============================] - 0s 1ms/step - loss: 5.0821e-06 - accuracy: 1.0000
# Epoch 47/100
# 24/24 [==============================] - 0s 1ms/step - loss: 4.8153e-06 - accuracy: 1.0000
# Epoch 48/100
# 24/24 [==============================] - 0s 1ms/step - loss: 4.5823e-06 - accuracy: 1.0000
# Epoch 49/100
# 24/24 [==============================] - 0s 1ms/step - loss: 4.3546e-06 - accuracy: 1.0000
# Epoch 50/100
# 24/24 [==============================] - 0s 1ms/step - loss: 4.1508e-06 - accuracy: 1.0000
# Epoch 51/100
# 24/24 [==============================] - 0s 1ms/step - loss: 3.9560e-06 - accuracy: 1.0000
# Epoch 52/100
# 24/24 [==============================] - 0s 1ms/step - loss: 3.7728e-06 - accuracy: 1.0000
# Epoch 53/100
# 24/24 [==============================] - 0s 1ms/step - loss: 3.6083e-06 - accuracy: 1.0000
# Epoch 54/100
# 24/24 [==============================] - 0s 1ms/step - loss: 3.4454e-06 - accuracy: 1.0000
# Epoch 55/100
# 24/24 [==============================] - 0s 1ms/step - loss: 3.3049e-06 - accuracy: 1.0000
# Epoch 56/100
# 24/24 [==============================] - 0s 1ms/step - loss: 3.1599e-06 - accuracy: 1.0000
# Epoch 57/100
# 24/24 [==============================] - 0s 1ms/step - loss: 3.0301e-06 - accuracy: 1.0000
# Epoch 58/100
# 24/24 [==============================] - 0s 1ms/step - loss: 2.9062e-06 - accuracy: 1.0000
# Epoch 59/100
# 24/24 [==============================] - 0s 1ms/step - loss: 2.7932e-06 - accuracy: 1.0000
# Epoch 60/100
# 24/24 [==============================] - 0s 1ms/step - loss: 2.6812e-06 - accuracy: 1.0000
# Epoch 61/100
# 24/24 [==============================] - 0s 1ms/step - loss: 2.5781e-06 - accuracy: 1.0000
# Epoch 62/100
# 24/24 [==============================] - 0s 1ms/step - loss: 2.4823e-06 - accuracy: 1.0000
# Epoch 63/100
# 24/24 [==============================] - 0s 1ms/step - loss: 2.3865e-06 - accuracy: 1.0000
# Epoch 64/100
# 24/24 [==============================] - 0s 1ms/step - loss: 2.3008e-06 - accuracy: 1.0000
# Epoch 65/100
# 24/24 [==============================] - 0s 1ms/step - loss: 2.2173e-06 - accuracy: 1.0000
# Epoch 66/100
# 24/24 [==============================] - 0s 1ms/step - loss: 2.1378e-06 - accuracy: 1.0000
# Epoch 67/100
# 24/24 [==============================] - 0s 1ms/step - loss: 2.0641e-06 - accuracy: 1.0000
# Epoch 68/100
# 24/24 [==============================] - 0s 1ms/step - loss: 1.9911e-06 - accuracy: 1.0000
# Epoch 69/100
# 24/24 [==============================] - 0s 1ms/step - loss: 1.9250e-06 - accuracy: 1.0000
# Epoch 70/100
# 24/24 [==============================] - 0s 1ms/step - loss: 1.8584e-06 - accuracy: 1.0000
# Epoch 71/100
# 24/24 [==============================] - 0s 1ms/step - loss: 1.7978e-06 - accuracy: 1.0000
# Epoch 72/100
# 24/24 [==============================] - 0s 1ms/step - loss: 1.7403e-06 - accuracy: 1.0000
# Epoch 73/100
# 24/24 [==============================] - 0s 1ms/step - loss: 1.6819e-06 - accuracy: 1.0000
# Epoch 74/100
# 24/24 [==============================] - 0s 1ms/step - loss: 1.6287e-06 - accuracy: 1.0000
# Epoch 75/100
# 24/24 [==============================] - 0s 1ms/step - loss: 1.5767e-06 - accuracy: 1.0000
# Epoch 76/100
# 24/24 [==============================] - 0s 1ms/step - loss: 1.5286e-06 - accuracy: 1.0000
# Epoch 77/100
# 24/24 [==============================] - 0s 1ms/step - loss: 1.4814e-06 - accuracy: 1.0000
# Epoch 78/100
# 24/24 [==============================] - 0s 1ms/step - loss: 1.4357e-06 - accuracy: 1.0000
# Epoch 79/100
# 24/24 [==============================] - 0s 1ms/step - loss: 1.3929e-06 - accuracy: 1.0000
# Epoch 80/100
# 24/24 [==============================] - 0s 1ms/step - loss: 1.3520e-06 - accuracy: 1.0000
# Epoch 81/100
# 24/24 [==============================] - 0s 1ms/step - loss: 1.3118e-06 - accuracy: 1.0000
# Epoch 82/100
# 24/24 [==============================] - 0s 1ms/step - loss: 1.2734e-06 - accuracy: 1.0000
# Epoch 83/100
# 24/24 [==============================] - 0s 1ms/step - loss: 1.2371e-06 - accuracy: 1.0000
# Epoch 84/100
# 24/24 [==============================] - 0s 1ms/step - loss: 1.2019e-06 - accuracy: 1.0000
# Epoch 85/100
# 24/24 [==============================] - 0s 1ms/step - loss: 1.1677e-06 - accuracy: 1.0000
# Epoch 86/100
# 24/24 [==============================] - 0s 1ms/step - loss: 1.1364e-06 - accuracy: 1.0000
# Epoch 87/100
# 24/24 [==============================] - 0s 1ms/step - loss: 1.1038e-06 - accuracy: 1.0000
# Epoch 88/100
# 24/24 [==============================] - 0s 1ms/step - loss: 1.0739e-06 - accuracy: 1.0000
# Epoch 89/100
# 24/24 [==============================] - 0s 1ms/step - loss: 1.0456e-06 - accuracy: 1.0000
# Epoch 90/100
# 24/24 [==============================] - 0s 1ms/step - loss: 1.0172e-06 - accuracy: 1.0000
# Epoch 91/100
# 24/24 [==============================] - 0s 1ms/step - loss: 9.9064e-07 - accuracy: 1.0000
# Epoch 92/100
# 24/24 [==============================] - 0s 1ms/step - loss: 9.6391e-07 - accuracy: 1.0000
# Epoch 93/100
# 24/24 [==============================] - 0s 1ms/step - loss: 9.3930e-07 - accuracy: 1.0000
# Epoch 94/100
# 24/24 [==============================] - 0s 1ms/step - loss: 9.1496e-07 - accuracy: 1.0000
# Epoch 95/100
# 24/24 [==============================] - 0s 1ms/step - loss: 8.9136e-07 - accuracy: 1.0000
# Epoch 96/100
# 24/24 [==============================] - 0s 1ms/step - loss: 8.6909e-07 - accuracy: 1.0000
# Epoch 97/100
# 24/24 [==============================] - 0s 1ms/step - loss: 8.4726e-07 - accuracy: 1.0000
# Epoch 98/100
# 24/24 [==============================] - 0s 1ms/step - loss: 8.2591e-07 - accuracy: 1.0000
# Epoch 99/100
# 24/24 [==============================] - 0s 1ms/step - loss: 8.0568e-07 - accuracy: 1.0000
# Epoch 100/100
# 24/24 [==============================] - 0s 1ms/step - loss: 7.8638e-07 - accuracy: 1.0000

# %%
# Out:
# For training:
# 24/24 [==============================] - 0s 1ms/step - loss: 7.7559e-07 - accuracy: 1.0000
# Losses: 7.755859883218363e-07
# Accuracy: 1.0
#
# For validation:
# 6/6 [==============================] - 0s 1ms/step - loss: 1.0982e-06 - accuracy: 1.0000
# Losses: 1.0981699460899108e-06
# Accuracy: 1.0

# %%
import os
import numpy as np
import keras
from keras import layers
from tensorflow import data as tf_data
import matplotlib.pyplot as plt
from keras.utils import to_categorical
import cv2
from PIL import Image

# %%
elephant_loc = "./train/elephant"
cow_loc = './train/cow'
squirrel_loc = './train/squirrel'
sheep_loc = './train/sheep'
butterfly_loc = './train/butterfly'
test_samples = './test'

path = "./train/"
categories = ["elephant", "cow", "squirrel", "sheep", "butterfly"]
for c in categories:
    figure, _ = plt.subplots(3, 3)
    figure.suptitle(c)
    for k, v in enumerate(os.listdir(path + c)[:9]):
        image = plt.imread(path + c + '/' + v)
        plt.subplot(3, 3, k+1)
        plt.imshow(image)
    plt.show()

# %%
num_skipped = 0
for folder_name in ("elephant", "cow", "squirrel", "sheep", "butterfly"):
    folder_path = os.path.join("./train/", folder_name)
    for fname in os.listdir(folder_path):
        fpath = os.path.join(folder_path, fname)
        try:
            fobj = open(fpath, "rb")
            is_jfif = b"JFIF" in fobj.peek(10)
        finally:
            fobj.close()

        if not is_jfif:
            num_skipped += 1
            os.remove(fpath)

print(f"Deleted {num_skipped} images.")
# Out:
# Deleted 0 images.

# %%
X = []
y = []
paths = []
path = "./train/"

for k, c in enumerate(categories):
    for f in os.listdir(path + c):
        paths.append([path + c + '/' + f, k])

for path in paths:
    image = cv2.imread(path[0])
    image = cv2.resize(image, (128, 128))
    X.append(image)
    
    label = path[1]
    y.append(label)
    
X = np.array(X, dtype="float") / 255
y = np.array(y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=123)
print(X_train.shape)
print(X_test.shape)
# Out:
# (7194, 128, 128, 3)
# (800, 128, 128, 3)

# %%
alpha = 0.02

model = keras.Sequential()

model.add(layers.Conv2D(filters=16, kernel_size=(3, 3), padding="same", input_shape=(X_train.shape[1:])))
model.add(layers.LeakyReLU(alpha=alpha))
model.add(layers.MaxPooling2D(pool_size=(2, 2), padding='same'))

model.add(layers.Conv2D(filters=32, kernel_size=(3, 3), padding="same"))
model.add(layers.LeakyReLU(alpha=alpha))
model.add(layers.MaxPooling2D(pool_size=(2, 2), padding='same'))

model.add(layers.Conv2D(filters=64, kernel_size=(3, 3), padding="same"))
model.add(layers.LeakyReLU(alpha=alpha))
model.add(layers.MaxPooling2D(pool_size=(2, 2), padding='same'))

model.add(layers.Flatten())

model.add(layers.Dense(512))
model.add(layers.LeakyReLU(alpha=alpha))

model.add(layers.Dense(5, activation="softmax")) #changed units from 1o to 5 to represent 5 classes

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\Andrii\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 128, 128, 16)      448
#
#  leaky_re_lu (LeakyReLU)     (None, 128, 128, 16)      0
#
#  max_pooling2d (MaxPooling2  (None, 64, 64, 16)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 64, 64, 32)        4640
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 64, 64, 32)        0
#
#  max_pooling2d_1 (MaxPoolin  (None, 32, 32, 32)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 64)        18496
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 32, 32, 64)        0
#
#  max_pooling2d_2 (MaxPoolin  (None, 16, 16, 64)        0
#  g2D)
#
#  flatten (Flatten)           (None, 16384)             0
#
#  dense_3 (Dense)             (None, 512)               8389120
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 512)               0
#
#  dense_4 (Dense)             (None, 5)                 2565
#
# =================================================================
# Total params: 8415269 (32.10 MB)
# Trainable params: 8415269 (32.10 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
my_callbacks = [keras.callbacks.EarlyStopping(patience = 25)]
model.fit(X_train, y_train, validation_data = (X_test, y_test), epochs = 50, batch_size = 50, callbacks = my_callbacks, verbose = 1)
# Out:
# Epoch 1/50
# 144/144 [==============================] - 24s 157ms/step - loss: 1.2498 - accuracy: 0.4893 - val_loss: 0.9078 - val_accuracy: 0.6438
# Epoch 2/50
# 144/144 [==============================] - 22s 155ms/step - loss: 0.7961 - accuracy: 0.7003 - val_loss: 0.7971 - val_accuracy: 0.7013
# Epoch 3/50
# 144/144 [==============================] - 22s 152ms/step - loss: 0.6362 - accuracy: 0.7601 - val_loss: 0.7074 - val_accuracy: 0.7462
# Epoch 4/50
# 144/144 [==============================] - 22s 150ms/step - loss: 0.4487 - accuracy: 0.8400 - val_loss: 0.7057 - val_accuracy: 0.7462
# Epoch 5/50
# 144/144 [==============================] - 21s 147ms/step - loss: 0.3059 - accuracy: 0.8925 - val_loss: 0.8385 - val_accuracy: 0.7387
# Epoch 6/50
# 144/144 [==============================] - 24s 168ms/step - loss: 0.1696 - accuracy: 0.9447 - val_loss: 0.9332 - val_accuracy: 0.7212
# Epoch 7/50
# 144/144 [==============================] - 22s 153ms/step - loss: 0.1268 - accuracy: 0.9576 - val_loss: 1.0402 - val_accuracy: 0.7200
# Epoch 8/50
# 144/144 [==============================] - 22s 150ms/step - loss: 0.0669 - accuracy: 0.9811 - val_loss: 1.1229 - val_accuracy: 0.7237
# Epoch 9/50
# 144/144 [==============================] - 21s 145ms/step - loss: 0.0497 - accuracy: 0.9861 - val_loss: 1.0728 - val_accuracy: 0.7487
# Epoch 10/50
# 144/144 [==============================] - 20s 141ms/step - loss: 0.0260 - accuracy: 0.9925 - val_loss: 1.3986 - val_accuracy: 0.7350
# Epoch 11/50
# 144/144 [==============================] - 21s 143ms/step - loss: 0.0156 - accuracy: 0.9964 - val_loss: 1.3322 - val_accuracy: 0.7500
# Epoch 12/50
# 144/144 [==============================] - 21s 145ms/step - loss: 0.0038 - accuracy: 0.9996 - val_loss: 1.4448 - val_accuracy: 0.7775
# Epoch 13/50
# 144/144 [==============================] - 21s 146ms/step - loss: 0.0010 - accuracy: 0.9999 - val_loss: 1.4667 - val_accuracy: 0.7825
# Epoch 14/50
# 144/144 [==============================] - 21s 147ms/step - loss: 0.0027 - accuracy: 0.9997 - val_loss: 1.5516 - val_accuracy: 0.7650
# Epoch 15/50
# 144/144 [==============================] - 23s 157ms/step - loss: 0.0231 - accuracy: 0.9933 - val_loss: 1.5007 - val_accuracy: 0.7237
# Epoch 16/50
# 144/144 [==============================] - 22s 156ms/step - loss: 0.0769 - accuracy: 0.9741 - val_loss: 1.2758 - val_accuracy: 0.7387
# Epoch 17/50
# 144/144 [==============================] - 23s 158ms/step - loss: 0.0380 - accuracy: 0.9883 - val_loss: 1.4562 - val_accuracy: 0.7225
# Epoch 18/50
# 144/144 [==============================] - 22s 156ms/step - loss: 0.0231 - accuracy: 0.9935 - val_loss: 1.5150 - val_accuracy: 0.7450
# Epoch 19/50
# 144/144 [==============================] - 22s 156ms/step - loss: 0.0185 - accuracy: 0.9946 - val_loss: 1.6250 - val_accuracy: 0.7487
# Epoch 20/50
# 144/144 [==============================] - 22s 152ms/step - loss: 0.0278 - accuracy: 0.9907 - val_loss: 1.6930 - val_accuracy: 0.7525
# Epoch 21/50
# 144/144 [==============================] - 22s 152ms/step - loss: 0.0091 - accuracy: 0.9972 - val_loss: 1.9284 - val_accuracy: 0.7312
# Epoch 22/50
# 144/144 [==============================] - 22s 151ms/step - loss: 0.0051 - accuracy: 0.9987 - val_loss: 1.8729 - val_accuracy: 0.7487
# Epoch 23/50
# 144/144 [==============================] - 22s 151ms/step - loss: 0.0327 - accuracy: 0.9890 - val_loss: 1.6810 - val_accuracy: 0.7425
# Epoch 24/50
# 144/144 [==============================] - 22s 151ms/step - loss: 0.0141 - accuracy: 0.9960 - val_loss: 1.7221 - val_accuracy: 0.7400
# Epoch 25/50
# 144/144 [==============================] - 22s 152ms/step - loss: 0.0191 - accuracy: 0.9944 - val_loss: 1.7714 - val_accuracy: 0.7262
# Epoch 26/50
# 144/144 [==============================] - 22s 152ms/step - loss: 0.0273 - accuracy: 0.9914 - val_loss: 1.7827 - val_accuracy: 0.7450
# Epoch 27/50
# 144/144 [==============================] - 22s 152ms/step - loss: 0.0047 - accuracy: 0.9989 - val_loss: 1.6913 - val_accuracy: 0.7400
# Epoch 28/50
# 144/144 [==============================] - 22s 151ms/step - loss: 0.0048 - accuracy: 0.9989 - val_loss: 1.9434 - val_accuracy: 0.7175
# Epoch 29/50
# 144/144 [==============================] - 22s 151ms/step - loss: 0.0025 - accuracy: 0.9994 - val_loss: 1.8390 - val_accuracy: 0.7412

# %%
print('For validation:')
results = model.evaluate(X_test, y_test)
print('1. Losses:', results[0])
print('2. Accuracy:', results[1])

print('For training:')
results = model.evaluate(X_train, y_train)
print('1. Losses:', results[0])
print('2. Accuracy:', results[1])
# Out:
# For validation:
# 25/25 [==============================] - 1s 17ms/step - loss: 1.8390 - accuracy: 0.7412
# 1. Losses: 1.8390378952026367
# 2. Accuracy: 0.7412499785423279
# For training:
# 225/225 [==============================] - 4s 19ms/step - loss: 4.9941e-04 - accuracy: 0.9999
# 1. Losses: 0.0004994146293029189
# 2. Accuracy: 0.9998610019683838

# %%
for i in range(3):
    idx = np.random.randint(0, len(X_test))
    img = X_test[idx]
    ani_class = y_test[idx]
    predict =  model.predict(np.array([img]), verbose=0)[0]
    pred_class = (predict/max(predict)).astype(int)
    
    if ani_class == 0:
        the_class = 'elephant'
    elif ani_class == 1:
        the_class = 'cow'
    elif ani_class == 2:
        the_class = 'squirrel'
    elif ani_class == 3:
        the_class = 'sheep'
    else:
        the_class = 'butterfly'
    
    pred_class = 'elephant' if pred_class[0] else 'cow' if pred_class[1] else 'squirrel' if pred_class[2] else 'sheep' if pred_class[3] else 'butterfly'

    array = (img * 255).astype(np.uint8).reshape((128, 128, 3))
    display(Image.fromarray(array).resize((512, 512)))
    print(f'The class: ->\t{the_class}\nPrediction ->\t{pred_class}\n\n\t>>> {100*predict[0]:.2f}% elephant --- {100*predict[1]:.2f}% cow --- {100*predict[2]:.2f}% squirrel --- {100*predict[3]:.2f}% sheep --- {100*predict[4]:.2f}% butterfly <<<\n\n\n')
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>
# The class: ->	elephant
# Prediction ->	elephant
#
# 	>>> 100.00% elephant --- 0.00% cow --- 0.00% squirrel --- 0.00% sheep --- 0.00% butterfly <<<
# <PIL.Image.Image image mode=RGB size=512x512>
# The class: ->	cow
# Prediction ->	cow
#
# 	>>> 1.98% elephant --- 96.98% cow --- 0.97% squirrel --- 0.00% sheep --- 0.07% butterfly <<<
# <PIL.Image.Image image mode=RGB size=512x512>
# The class: ->	cow
# Prediction ->	cow
#
# 	>>> 0.00% elephant --- 100.00% cow --- 0.00% squirrel --- 0.00% sheep --- 0.00% butterfly <<<

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn import preprocessing
import chardet
from keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split
import keras
import numpy as np
from tensorflow.keras.layers import Dense, Activation, Flatten, Conv2D, MaxPool2D, Embedding, LSTM
import matplotlib.pyplot as plt

# %%
ds = pd.read_csv('spotify-2023.csv', encoding='latin-1')
ds.keys()
# Out:
# Index(['track_name', 'artist(s)_name', 'artist_count', 'released_year',
#        'released_month', 'released_day', 'in_spotify_playlists',
#        'in_spotify_charts', 'streams', 'in_apple_playlists', 'in_apple_charts',
#        'in_deezer_playlists', 'in_deezer_charts', 'in_shazam_charts', 'bpm',
#        'key', 'mode', 'danceability_%', 'valence_%', 'energy_%',
#        'acousticness_%', 'instrumentalness_%', 'liveness_%', 'speechiness_%'],
#       dtype='object')

# %%
with open('spotify-2023.csv', 'rb') as f:
    result = chardet.detect(f.read())
    
ds = pd.read_csv('spotify-2023.csv', encoding=result['encoding'])
ds = ds.drop(columns=['artist(s)_name', 'artist_count', 'released_year', 'released_month', 'released_day', 'in_spotify_playlists', 'streams', 'in_apple_playlists', 'in_apple_charts', 'in_deezer_playlists', 'in_deezer_charts', 'in_shazam_charts', 'bpm', 'key', 'mode', 'danceability_%', 'valence_%', 'energy_%', 'acousticness_%', 'instrumentalness_%', 'liveness_%', 'speechiness_%'], axis = 1)
ds = ds.rename(columns={"track_name":"track", "in_spotify_charts":"chart"})

cols_to_check = ['track','chart'] #text and label
ds[cols_to_check] = ds[cols_to_check].replace({'½':''}, regex=True)
ds[cols_to_check] = ds[cols_to_check].replace({'ï':''}, regex=True)
ds[cols_to_check] = ds[cols_to_check].replace({'¿':''}, regex=True)
ds.loc[ds["chart"] < 10, "chart"] = 1 #very popular
ds.loc[ds["chart"] >= 10, "chart"] = 0 #not that popular
ds.head()
# Out:
#                                  track  chart
# 0  Seven (feat. Latto) (Explicit Ver.)      0
# 1                                 LALA      0
# 2                              vampire      0
# 3                         Cruel Summer      0
# 4                       WHERE SHE GOES      0

# %%
X = ds['track']
y = ds['chart']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123)

# %%
token = Tokenizer(lower=False)
token.fit_on_texts(X_train)
X_train = token.texts_to_sequences(X_train)
X_test = token.texts_to_sequences(X_test)

array = []
for i in X_train:
    array.append(len(i))
maxlen = int(np.ceil(np.mean(array))) # вирівнюємо довжину

X_train = pad_sequences(X_train, maxlen=maxlen)
X_test = pad_sequences(X_test, maxlen=maxlen)
total_words = len(token.word_index) + 1

# %%
model = keras.Sequential()
model.add(Embedding(total_words, 32, input_length= maxlen))
model.add(LSTM(10, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', metrics=['accuracy'], optimizer='adam')
lol = model.fit(X_train, y_train, epochs=50, batch_size=32)
# Out:
# Epoch 1/50
# 24/24 [==============================] - 3s 4ms/step - loss: 0.6876 - accuracy: 0.6483
# Epoch 2/50
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6696 - accuracy: 0.6706
# Epoch 3/50
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6432 - accuracy: 0.6706
# Epoch 4/50
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6076 - accuracy: 0.6706
# Epoch 5/50
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5601 - accuracy: 0.6745
# Epoch 6/50
# 24/24 [==============================] - 0s 3ms/step - loss: 0.4929 - accuracy: 0.6929
# Epoch 7/50
# 24/24 [==============================] - 0s 3ms/step - loss: 0.4211 - accuracy: 0.7493
# Epoch 8/50
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3556 - accuracy: 0.8294
# Epoch 9/50
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2991 - accuracy: 0.9121
# Epoch 10/50
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2533 - accuracy: 0.9501
# Epoch 11/50
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2160 - accuracy: 0.9738
# Epoch 12/50
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1852 - accuracy: 0.9882
# Epoch 13/50
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1634 - accuracy: 0.9908
# Epoch 14/50
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1393 - accuracy: 0.9869
# Epoch 15/50
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1206 - accuracy: 0.9869
# Epoch 16/50
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1053 - accuracy: 0.9895
# Epoch 17/50
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0901 - accuracy: 0.9934
# Epoch 18/50
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0753 - accuracy: 0.9921
# Epoch 19/50
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0630 - accuracy: 0.9948
# Epoch 20/50
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0567 - accuracy: 0.9948
# Epoch 21/50
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0566 - accuracy: 0.9882
# Epoch 22/50
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0440 - accuracy: 0.9961
# Epoch 23/50
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0408 - accuracy: 0.9934
# Epoch 24/50
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0416 - accuracy: 0.9908
# Epoch 25/50
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0345 - accuracy: 0.9921
# Epoch 26/50
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0307 - accuracy: 0.9948
# Epoch 27/50
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0245 - accuracy: 0.9961
# Epoch 28/50
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0268 - accuracy: 0.9961
# Epoch 29/50
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0270 - accuracy: 0.9921
# Epoch 30/50
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0283 - accuracy: 0.9934
# Epoch 31/50
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0203 - accuracy: 0.9961
# Epoch 32/50
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0238 - accuracy: 0.9948
# Epoch 33/50
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0208 - accuracy: 0.9908
# Epoch 34/50
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0200 - accuracy: 0.9948
# Epoch 35/50
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0218 - accuracy: 0.9908
# Epoch 36/50
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0223 - accuracy: 0.9921
# Epoch 37/50
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0171 - accuracy: 0.9921
# Epoch 38/50
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0192 - accuracy: 0.9948
# Epoch 39/50
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0154 - accuracy: 0.9961
# Epoch 40/50
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0148 - accuracy: 0.9961
# Epoch 41/50
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0165 - accuracy: 0.9934
# Epoch 42/50
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0147 - accuracy: 0.9961
# Epoch 43/50
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0170 - accuracy: 0.9934
# Epoch 44/50
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0154 - accuracy: 0.9961
# Epoch 45/50
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0205 - accuracy: 0.9908
# Epoch 46/50
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0146 - accuracy: 0.9948
# Epoch 47/50
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0174 - accuracy: 0.9934
# Epoch 48/50
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0197 - accuracy: 0.9934
# Epoch 49/50
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0124 - accuracy: 0.9961
# Epoch 50/50
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0142 - accuracy: 0.9948

# %%
results = model.evaluate(X_train, y_train, verbose=0)
print('Losses:', results[0])
print('Accuracy:', results[1])
# Out:
# Losses: 0.011279438622295856
# Accuracy: 0.9947506785392761

# %%
plt.figure(figsize=(6,3))
plt.plot(lol.history['loss'])
plt.plot(lol.history['accuracy'])
plt.ylabel('Losses')
plt.xlabel('Accuracy')
plt.legend(['Losses', 'Accuracy'], bbox_to_anchor = (1, 1))
plt.show()
